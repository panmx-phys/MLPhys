# %%
import matplotlib.pyplot as plt
import numpy as np
import pickle
from scanFun import *
import datetime

# %%
beta_scan = np.arange(0.01,10,step = 0.1)

fullRes = np.zeros((beta_scan.size,3))

dataPath = "data/"
for layer in range(1,3):
    i = 1
    for beta in beta_scan:
        if i % 10 == 0:
            np.save(dataPath  +str(datetime.datetime.now())[:-10],fullRes)
            print(layer,i)
        est, truth = QCCalc(beta,0.5,0.5,layer)
        fullRes[i-1,layer] = est
        fullRes[i-1,-1] = truth
        i+= 1
# Out:
# /Users/qwe/MLPhys/QC/pure/QCutils.py:97: ComplexWarning: Casting complex values to real discards the imaginary part
#   thetaGrad[i] = grad1
# /Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_lbfgsb_py.py:353: ComplexWarning: Casting complex values to real discards the imaginary part
#   _lbfgsb.setulb(m, x, low_bnd, upper_bnd, nbd, f, g, factr,
# /Users/qwe/MLPhys/QC/pure/scanFun.py:139: ComplexWarning: Casting complex values to real discards the imaginary part
#   return results.fun,float(-np.log(np.trace(expm(- beta * H))))
# /var/folders/2_/8rs1gbh95pd73jb7n34phc980000gn/T/ipykernel_61287/1619899864.py:13: ComplexWarning: Casting complex values to real discards the imaginary part
#   fullRes[i-1,layer] = est
# 1 10
# 1 20
# 1 30
# 1 40
# 1 50
# 1 60
# 1 70
# 1 80
# 1 90
# 1 100
# 2 10
# 2 20
# 2 30
# 2 40
# 2 50
# 2 60
# 2 70
# 2 80
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/qwe/MLPhys/QC/pure/pureQCScan.ipynb Cell 2' in <module>
#      <a href='vscode-notebook-cell:/Users/qwe/MLPhys/QC/pure/pureQCScan.ipynb#ch0000001?line=9'>10</a>     np.save(dataPath  +str(datetime.datetime.now())[:-10],fullRes)
#      <a href='vscode-notebook-cell:/Users/qwe/MLPhys/QC/pure/pureQCScan.ipynb#ch0000001?line=10'>11</a>     print(layer,i)
# ---> <a href='vscode-notebook-cell:/Users/qwe/MLPhys/QC/pure/pureQCScan.ipynb#ch0000001?line=11'>12</a> est, truth = QCCalc(beta,0.5,0.5,layer)
#      <a href='vscode-notebook-cell:/Users/qwe/MLPhys/QC/pure/pureQCScan.ipynb#ch0000001?line=12'>13</a> fullRes[i-1,layer] = est
#      <a href='vscode-notebook-cell:/Users/qwe/MLPhys/QC/pure/pureQCScan.ipynb#ch0000001?line=13'>14</a> fullRes[i-1,-1] = truth
#
# File ~/MLPhys/QC/pure/scanFun.py:137, in QCCalc(beta, J, h, layerNum)
#     <a href='file:///Users/qwe/MLPhys/QC/pure/scanFun.py?line=131'>132</a>     return test1.calc(), test1.getThetaGrad()
#     <a href='file:///Users/qwe/MLPhys/QC/pure/scanFun.py?line=135'>136</a> initThetas = 2* np.pi * np.random.rand(test1.size())
# --> <a href='file:///Users/qwe/MLPhys/QC/pure/scanFun.py?line=136'>137</a> results = scipy.optimize.minimize(ValandGrad, initThetas,
#     <a href='file:///Users/qwe/MLPhys/QC/pure/scanFun.py?line=137'>138</a>                                 method='L-BFGS-B', jac=True)
#     <a href='file:///Users/qwe/MLPhys/QC/pure/scanFun.py?line=138'>139</a> return results.fun,float(-np.log(np.trace(expm(- beta * H))))
#
# File ~/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_minimize.py:681, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_minimize.py?line=677'>678</a>     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_minimize.py?line=678'>679</a>                              **options)
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_minimize.py?line=679'>680</a> elif meth == 'l-bfgs-b':
# --> <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_minimize.py?line=680'>681</a>     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_minimize.py?line=681'>682</a>                            callback=callback, **options)
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_minimize.py?line=682'>683</a> elif meth == 'tnc':
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_minimize.py?line=683'>684</a>     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_minimize.py?line=684'>685</a>                         **options)
#
# File ~/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_lbfgsb_py.py:362, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_lbfgsb_py.py?line=355'>356</a> task_str = task.tobytes()
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_lbfgsb_py.py?line=356'>357</a> if task_str.startswith(b'FG'):
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_lbfgsb_py.py?line=357'>358</a>     # The minimization routine wants f and g at the current x.
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_lbfgsb_py.py?line=358'>359</a>     # Note that interruptions due to maxfun are postponed
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_lbfgsb_py.py?line=359'>360</a>     # until the completion of the current minimization iteration.
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_lbfgsb_py.py?line=360'>361</a>     # Overwrite f and g:
# --> <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_lbfgsb_py.py?line=361'>362</a>     f, g = func_and_grad(x)
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_lbfgsb_py.py?line=362'>363</a> elif task_str.startswith(b'NEW_X'):
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_lbfgsb_py.py?line=363'>364</a>     # new iteration
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_lbfgsb_py.py?line=364'>365</a>     n_iterations += 1
#
# File ~/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py:285, in ScalarFunction.fun_and_grad(self, x)
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py?line=282'>283</a> if not np.array_equal(x, self.x):
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py?line=283'>284</a>     self._update_x_impl(x)
# --> <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py?line=284'>285</a> self._update_fun()
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py?line=285'>286</a> self._update_grad()
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py?line=286'>287</a> return self.f, self.g
#
# File ~/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py:251, in ScalarFunction._update_fun(self)
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py?line=248'>249</a> def _update_fun(self):
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py?line=249'>250</a>     if not self.f_updated:
# --> <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py?line=250'>251</a>         self._update_fun_impl()
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py?line=251'>252</a>         self.f_updated = True
#
# File ~/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py:155, in ScalarFunction.__init__.<locals>.update_fun()
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py?line=153'>154</a> def update_fun():
# --> <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py?line=154'>155</a>     self.f = fun_wrapped(self.x)
#
# File ~/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py:137, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py?line=132'>133</a> self.nfev += 1
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py?line=133'>134</a> # Send a copy because the user may overwrite it.
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py?line=134'>135</a> # Overwriting results in undefined behaviour because
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py?line=135'>136</a> # fun(self.x) will change self.x, with the two no longer linked.
# --> <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py?line=136'>137</a> fx = fun(np.copy(x), *args)
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py?line=137'>138</a> # Make sure the function returns a true scalar
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py?line=138'>139</a> if not np.isscalar(fx):
#
# File ~/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_optimize.py:76, in MemoizeJac.__call__(self, x, *args)
#      <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_optimize.py?line=73'>74</a> def __call__(self, x, *args):
#      <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_optimize.py?line=74'>75</a>     """ returns the the function value """
# ---> <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_optimize.py?line=75'>76</a>     self._compute_if_needed(x, *args)
#      <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_optimize.py?line=76'>77</a>     return self._value
#
# File ~/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_optimize.py:70, in MemoizeJac._compute_if_needed(self, x, *args)
#      <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_optimize.py?line=67'>68</a> if not np.all(x == self.x) or self._value is None or self.jac is None:
#      <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_optimize.py?line=68'>69</a>     self.x = np.asarray(x).copy()
# ---> <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_optimize.py?line=69'>70</a>     fg = self.fun(x, *args)
#      <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_optimize.py?line=70'>71</a>     self.jac = fg[1]
#      <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/scipy/optimize/_optimize.py?line=71'>72</a>     self._value = fg[0]
#
# File ~/MLPhys/QC/pure/scanFun.py:132, in QCCalc.<locals>.ValandGrad(thetas)
#     <a href='file:///Users/qwe/MLPhys/QC/pure/scanFun.py?line=129'>130</a> def ValandGrad(thetas):
#     <a href='file:///Users/qwe/MLPhys/QC/pure/scanFun.py?line=130'>131</a>     test1.updateThetas(thetas)
# --> <a href='file:///Users/qwe/MLPhys/QC/pure/scanFun.py?line=131'>132</a>     return test1.calc(), test1.getThetaGrad()
#
# File ~/MLPhys/QC/pure/QCutils.py:95, in QuCircWithGrad.getThetaGrad(self)
#      <a href='file:///Users/qwe/MLPhys/QC/pure/QCutils.py?line=92'>93</a> for i in range(self.size()):
#      <a href='file:///Users/qwe/MLPhys/QC/pure/QCutils.py?line=93'>94</a>     circPlus, circMinus = circList[i]
# ---> <a href='file:///Users/qwe/MLPhys/QC/pure/QCutils.py?line=94'>95</a>     grad1 = r * (circPlus.calc() - circMinus.calc())
#      <a href='file:///Users/qwe/MLPhys/QC/pure/QCutils.py?line=95'>96</a>     assert np.abs(np.imag(grad1)) < 0.001
#      <a href='file:///Users/qwe/MLPhys/QC/pure/QCutils.py?line=96'>97</a>     thetaGrad[i] = grad1
#
# File ~/MLPhys/QC/pure/QCutils.py:147, in QuCircWithGrad.calc(self)
#     <a href='file:///Users/qwe/MLPhys/QC/pure/QCutils.py?line=143'>144</a> def calc(self):
#     <a href='file:///Users/qwe/MLPhys/QC/pure/QCutils.py?line=145'>146</a>     backend = Aer.get_backend('qasm_simulator')
# --> <a href='file:///Users/qwe/MLPhys/QC/pure/QCutils.py?line=146'>147</a>     job = execute(self.qc, backend, shots=self.simShots)
#     <a href='file:///Users/qwe/MLPhys/QC/pure/QCutils.py?line=147'>148</a>     res = job.result().get_counts(self.qc)
#     <a href='file:///Users/qwe/MLPhys/QC/pure/QCutils.py?line=148'>149</a>     cost = self.costFun(res)
#
# File ~/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/execute_function.py:294, in execute(experiments, backend, basis_gates, coupling_map, backend_properties, initial_layout, seed_transpiler, optimization_level, pass_manager, qobj_id, qobj_header, shots, memory, max_credits, seed_simulator, default_qubit_los, default_meas_los, qubit_lo_range, meas_lo_range, schedule_los, meas_level, meas_return, memory_slots, memory_slot_size, rep_time, rep_delay, parameter_binds, schedule_circuit, inst_map, meas_map, scheduling_method, init_qubits, **run_config)
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/execute_function.py?line=290'>291</a>     experiments = pass_manager.run(experiments)
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/execute_function.py?line=291'>292</a> else:
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/execute_function.py?line=292'>293</a>     # transpiling the circuits using given transpile options
# --> <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/execute_function.py?line=293'>294</a>     experiments = transpile(
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/execute_function.py?line=294'>295</a>         experiments,
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/execute_function.py?line=295'>296</a>         basis_gates=basis_gates,
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/execute_function.py?line=296'>297</a>         coupling_map=coupling_map,
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/execute_function.py?line=297'>298</a>         backend_properties=backend_properties,
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/execute_function.py?line=298'>299</a>         initial_layout=initial_layout,
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/execute_function.py?line=299'>300</a>         seed_transpiler=seed_transpiler,
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/execute_function.py?line=300'>301</a>         optimization_level=optimization_level,
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/execute_function.py?line=301'>302</a>         backend=backend,
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/execute_function.py?line=302'>303</a>     )
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/execute_function.py?line=304'>305</a> if schedule_circuit:
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/execute_function.py?line=305'>306</a>     experiments = schedule(
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/execute_function.py?line=306'>307</a>         circuits=experiments,
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/execute_function.py?line=307'>308</a>         backend=backend,
#    (...)
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/execute_function.py?line=310'>311</a>         method=scheduling_method,
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/execute_function.py?line=311'>312</a>     )
#
# File ~/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/compiler/transpiler.py:335, in transpile(circuits, backend, basis_gates, inst_map, coupling_map, backend_properties, initial_layout, layout_method, routing_method, translation_method, scheduling_method, instruction_durations, dt, approximation_degree, timing_constraints, seed_transpiler, optimization_level, pass_manager, callback, output_name, unitary_synthesis_method, unitary_synthesis_plugin_config, target)
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/compiler/transpiler.py?line=331'>332</a> _check_circuits_coupling_map(circuits, transpile_args, backend)
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/compiler/transpiler.py?line=333'>334</a> # Transpile circuits in parallel
# --> <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/compiler/transpiler.py?line=334'>335</a> circuits = parallel_map(_transpile_circuit, list(zip(circuits, transpile_args)))
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/compiler/transpiler.py?line=336'>337</a> end_time = time()
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/compiler/transpiler.py?line=337'>338</a> _log_transpile_time(start_time, end_time)
#
# File ~/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/tools/parallel.py:132, in parallel_map(task, values, task_args, task_kwargs, num_processes)
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/tools/parallel.py?line=129'>130</a>     return []
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/tools/parallel.py?line=130'>131</a> if len(values) == 1:
# --> <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/tools/parallel.py?line=131'>132</a>     return [task(values[0], *task_args, **task_kwargs)]
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/tools/parallel.py?line=133'>134</a> Publisher().publish("terra.parallel.start", len(values))
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/tools/parallel.py?line=134'>135</a> nfinished = [0]
#
# File ~/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/compiler/transpiler.py:421, in _transpile_circuit(circuit_config_tuple)
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/compiler/transpiler.py?line=418'>419</a>     pass_manager = level_0_pass_manager(pass_manager_config)
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/compiler/transpiler.py?line=419'>420</a> elif level == 1:
# --> <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/compiler/transpiler.py?line=420'>421</a>     pass_manager = level_1_pass_manager(pass_manager_config)
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/compiler/transpiler.py?line=421'>422</a> elif level == 2:
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/compiler/transpiler.py?line=422'>423</a>     pass_manager = level_2_pass_manager(pass_manager_config)
#
# File ~/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/transpiler/preset_passmanagers/level1.py:106, in level_1_pass_manager(pass_manager_config)
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/transpiler/preset_passmanagers/level1.py?line=102'>103</a> target = pass_manager_config.target
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/transpiler/preset_passmanagers/level1.py?line=104'>105</a> # 1. Use trivial layout if no layout given
# --> <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/transpiler/preset_passmanagers/level1.py?line=105'>106</a> _given_layout = SetLayout(initial_layout)
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/transpiler/preset_passmanagers/level1.py?line=107'>108</a> _choose_layout_and_score = [
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/transpiler/preset_passmanagers/level1.py?line=108'>109</a>     TrivialLayout(coupling_map),
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/transpiler/preset_passmanagers/level1.py?line=109'>110</a>     Layout2qDistance(coupling_map, property_name="trivial_layout_score"),
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/transpiler/preset_passmanagers/level1.py?line=110'>111</a> ]
#     <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/transpiler/preset_passmanagers/level1.py?line=112'>113</a> def _choose_layout_condition(property_set):
#
# File ~/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/transpiler/basepasses.py:30, in MetaPass.__call__(cls, *args, **kwargs)
#      <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/transpiler/basepasses.py?line=27'>28</a> def __call__(cls, *args, **kwargs):
#      <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/transpiler/basepasses.py?line=28'>29</a>     pass_instance = type.__call__(cls, *args, **kwargs)
# ---> <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/transpiler/basepasses.py?line=29'>30</a>     pass_instance._hash = hash(MetaPass._freeze_init_parameters(cls, args, kwargs))
#      <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/transpiler/basepasses.py?line=30'>31</a>     return pass_instance
#
# File ~/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/transpiler/basepasses.py:36, in MetaPass._freeze_init_parameters(class_, args, kwargs)
#      <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/transpiler/basepasses.py?line=32'>33</a> @staticmethod
#      <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/transpiler/basepasses.py?line=33'>34</a> def _freeze_init_parameters(class_, args, kwargs):
#      <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/transpiler/basepasses.py?line=34'>35</a>     self_guard = object()
# ---> <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/transpiler/basepasses.py?line=35'>36</a>     init_signature = signature(class_.__init__)
#      <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/transpiler/basepasses.py?line=36'>37</a>     bound_signature = init_signature.bind(self_guard, *args, **kwargs)
#      <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/site-packages/qiskit/transpiler/basepasses.py?line=37'>38</a>     arguments = [("class_.__name__", class_.__name__)]
#
# File ~/miniforge3/envs/qi/lib/python3.10/inspect.py:3247, in signature(obj, follow_wrapped, globals, locals, eval_str)
#    <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/inspect.py?line=3244'>3245</a> def signature(obj, *, follow_wrapped=True, globals=None, locals=None, eval_str=False):
#    <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/inspect.py?line=3245'>3246</a>     """Get a signature object for the passed callable."""
# -> <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/inspect.py?line=3246'>3247</a>     return Signature.from_callable(obj, follow_wrapped=follow_wrapped,
#    <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/inspect.py?line=3247'>3248</a>                                    globals=globals, locals=locals, eval_str=eval_str)
#
# File ~/miniforge3/envs/qi/lib/python3.10/inspect.py:2995, in Signature.from_callable(cls, obj, follow_wrapped, globals, locals, eval_str)
#    <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/inspect.py?line=2990'>2991</a> @classmethod
#    <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/inspect.py?line=2991'>2992</a> def from_callable(cls, obj, *,
#    <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/inspect.py?line=2992'>2993</a>                   follow_wrapped=True, globals=None, locals=None, eval_str=False):
#    <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/inspect.py?line=2993'>2994</a>     """Constructs Signature for the given callable object."""
# -> <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/inspect.py?line=2994'>2995</a>     return _signature_from_callable(obj, sigcls=cls,
#    <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/inspect.py?line=2995'>2996</a>                                     follow_wrapper_chains=follow_wrapped,
#    <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/inspect.py?line=2996'>2997</a>                                     globals=globals, locals=locals, eval_str=eval_str)
#
# File ~/miniforge3/envs/qi/lib/python3.10/inspect.py:2456, in _signature_from_callable(obj, follow_wrapper_chains, skip_bound_arg, globals, locals, eval_str, sigcls)
#    <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/inspect.py?line=2450'>2451</a>             return sig.replace(parameters=new_params)
#    <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/inspect.py?line=2452'>2453</a> if isfunction(obj) or _signature_is_functionlike(obj):
#    <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/inspect.py?line=2453'>2454</a>     # If it's a pure Python function, or an object that is duck type
#    <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/inspect.py?line=2454'>2455</a>     # of a Python function (Cython functions, for instance), then:
# -> <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/inspect.py?line=2455'>2456</a>     return _signature_from_function(sigcls, obj,
#    <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/inspect.py?line=2456'>2457</a>                                     skip_bound_arg=skip_bound_arg,
#    <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/inspect.py?line=2457'>2458</a>                                     globals=globals, locals=locals, eval_str=eval_str)
#    <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/inspect.py?line=2459'>2460</a> if _signature_is_builtin(obj):
#    <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/inspect.py?line=2460'>2461</a>     return _signature_from_builtin(sigcls, obj,
#    <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/inspect.py?line=2461'>2462</a>                                    skip_bound_arg=skip_bound_arg)
#
# File ~/miniforge3/envs/qi/lib/python3.10/inspect.py:2366, in _signature_from_function(cls, func, skip_bound_arg, globals, locals, eval_str)
#    <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/inspect.py?line=2360'>2361</a>     parameters.append(Parameter(name, annotation=annotation,
#    <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/inspect.py?line=2361'>2362</a>                                 kind=_VAR_KEYWORD))
#    <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/inspect.py?line=2363'>2364</a> # Is 'func' is a pure Python function - don't validate the
#    <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/inspect.py?line=2364'>2365</a> # parameters list (for correct order and defaults), it should be OK.
# -> <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/inspect.py?line=2365'>2366</a> return cls(parameters,
#    <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/inspect.py?line=2366'>2367</a>            return_annotation=annotations.get('return', _empty),
#    <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/inspect.py?line=2367'>2368</a>            __validate_parameters__=is_duck_function)
#
# File ~/miniforge3/envs/qi/lib/python3.10/inspect.py:2919, in Signature.__init__(self, parameters, return_annotation, __validate_parameters__)
#    <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/inspect.py?line=2912'>2913</a> def __init__(self, parameters=None, *, return_annotation=_empty,
#    <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/inspect.py?line=2913'>2914</a>              __validate_parameters__=True):
#    <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/inspect.py?line=2914'>2915</a>     """Constructs Signature from the given list of Parameter
#    <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/inspect.py?line=2915'>2916</a>     objects and 'return_annotation'.  All arguments are optional.
#    <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/inspect.py?line=2916'>2917</a>     """
# -> <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/inspect.py?line=2918'>2919</a>     if parameters is None:
#    <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/inspect.py?line=2919'>2920</a>         params = OrderedDict()
#    <a href='file:///Users/qwe/miniforge3/envs/qi/lib/python3.10/inspect.py?line=2920'>2921</a>     else:
#
# KeyboardInterrupt:

# %%
beta_scan = np.arange(0.01,10,step = 0.1)

resEst = np.zeros_like(beta_scan)
resTrue = np.zeros_like(beta_scan)
dataPath = "data/FourLayer"
i = 1
for beta in beta_scan:
    est = plainCalc(beta,0.5,0.5,3)
    resEst[i-1] = est
    i+= 1

    np.save(dataPath + "Plain " +str(datetime.datetime.now())[:-10],resEst)
# Out:
# /Users/qwe/MLPhys/QC/pure/scanFun.py:197: ComplexWarning: Casting complex values to real discards the imaginary part
#   return float(-np.log(np.trace(expm(- beta * H))))

# %%
np.save("Estimate " +str(datetime.datetime.now())[:-10],resEst)

# %%
plt.scatter(beta_scan,resEst,s=0.5)

# %%
resEst
# Out:
# array([ -2.56269551,  -2.83417871,  -2.43692059,  -2.32180161,
#         -2.79320019,  -2.44132985,  -3.02396413,  -2.55076105,
#         -3.01380349,  -2.75556084,  -3.07021991,  -3.30651107,
#         -1.59646865,  -3.89383953,  -3.81070406,  -4.06137966,
#         -4.44847946,  -4.44371629,  -4.88335433,  -5.03100354,
#         -5.11077006,  -5.3712994 ,  -5.56674326,  -5.80144526,
#         -6.05927809,  -1.39478908,  -6.58578678,  -6.83126698,
#         -7.06011577,  -7.27700636,  -7.53347828,  -7.77979726,
#         -8.04245885,  -8.28280721,  -8.52113672,  -8.77939726,
#         -9.05188796,  -9.27919726,  -9.525     ,  -9.77401321,
#        -10.03951442,  -2.36271328, -10.53641794, -10.77859726,
#        -11.025     , -11.27388726, -11.52757412, -11.76132996,
#        -12.02637672, -12.25007783, -12.52789726, -12.75268638,
#        -13.01727726, -13.27880721, -13.525     ,  -3.11462675,
#        -14.02842907, -14.27719726, -14.525     , -14.775     ,
#        -15.02689726, -15.27232108, -15.525     , -15.775     ,
#        -16.025     , -16.21064312, -12.05839836, -16.77619726,
#        -17.025     , -17.275     , -17.525     , -17.775     ,
#        -18.025     , -18.27559726, -18.52549726, -18.775     ,
#        -19.025     , -19.27519726, -19.49395351, -19.76708351,
#         -4.21007001, -20.275     , -20.525     , -20.75757351,
#        -20.94106545, -21.21875042, -21.51568726, -21.775     ,
#        -22.025     , -22.275     , -22.525     , -22.775     ,
#        -23.025     , -23.27359726, -23.52349726, -23.775     ,
#         -4.92157152, -24.23896415, -24.49176351, -24.77299726])
